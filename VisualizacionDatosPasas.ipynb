# %%
# Libreria importantes para la Tarea
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import mode
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score,confusion_matrix

# Se corre una vez para mezclar el dataset y se usa el mezclado
dataSet = pd.read_csv("Raisin_Dataset.csv")

dataSet.describe()
# Out:
#                 Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count     900.000000       900.000000       900.000000    900.000000
# mean    87804.127778       430.929950       254.488133      0.781542
# std     39002.111390       116.035121        49.988902      0.090318
# min     25387.000000       225.629541       143.710872      0.348730
# 25%     59348.000000       345.442898       219.111126      0.741766
# 50%     78902.000000       407.803951       247.848409      0.798846
# 75%    105028.250000       494.187014       279.888575      0.842571
# max    235047.000000       997.291941       492.275279      0.962124
#
#           ConvexArea      Extent    Perimeter
# count     900.000000  900.000000   900.000000
# mean    91186.090000    0.699508  1165.906636
# std     40769.290132    0.053468   273.764315
# min     26139.000000    0.379856   619.074000
# 25%     61513.250000    0.670869   966.410750
# 50%     81651.000000    0.707367  1119.509000
# ...

# %%
sns.set_theme()
plt.figure(figsize=(10, 8))
sns.displot(data=dataSet, x="Area",kde=True, hue="Class", palette='Set1')

plt.show()
# Out:
# c:\Users\tian_\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme()
plt.figure(figsize=(10, 8))
sns.displot(data=dataSet, x="MajorAxisLength",kde=True, hue="Class", palette='Set1')

plt.show()
# Out:
# c:\Users\tian_\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme()
plt.figure(figsize=(10, 8))
sns.displot(data=dataSet, x="MinorAxisLength", hue="Class", palette='Set1',kde=True)

plt.show()
# Out:
# c:\Users\tian_\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme()
plt.figure(figsize=(10, 8))
sns.displot(data=dataSet, x="Eccentricity", hue="Class", palette='Set1',kde=True)

plt.show()
# Out:
# c:\Users\tian_\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme()
plt.figure(figsize=(10, 8))
sns.displot(data=dataSet, x="ConvexArea", hue="Class", palette='Set1',kde=True)

plt.show()
# Out:
# c:\Users\tian_\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme()
plt.figure(figsize=(10, 8))
sns.displot(data=dataSet, x="Extent", hue="Class", palette='Set1',kde=True)

plt.show()
# Out:
# c:\Users\tian_\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.set_theme()
plt.figure(figsize=(10, 8))
sns.displot(data=dataSet, x="Perimeter", hue="Class", palette='Set1',kde=True)

plt.show()
# Out:
# c:\Users\tian_\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
#Divicion del traning y testing dataset 80 - 20
# Se quita la especies del de prueba


dataFrameTraining, dataFrameTesting = train_test_split(dataSet, test_size=0.2, random_state=42)

DataSetTestingLimpio = dataFrameTesting.drop(columns=["Class"])

dataFrameTesting.to_csv('DataSetTesting.csv', index=False)
DataSetTestingLimpio.to_csv('DataSetTestingLimpio.csv', index=False)

# %%
dataFrameTraining.describe()
# Out:
#                 Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count     720.000000       720.000000       720.000000    720.000000
# mean    88194.894444       432.160303       254.884952      0.782094
# std     39298.256057       116.170902        50.573318      0.091319
# min     25387.000000       225.629541       143.710872      0.348730
# 25%     59873.000000       346.879137       218.845506      0.741830
# 50%     79056.000000       407.617248       248.119537      0.800636
# 75%    105221.000000       496.362582       281.707510      0.845098
# max    235047.000000       997.291941       492.275279      0.962124
#
#           ConvexArea      Extent    Perimeter
# count     720.000000  720.000000   720.000000
# mean    91604.247222    0.699235  1168.854746
# std     40948.702809    0.054961   273.594388
# min     26139.000000    0.379856   619.074000
# 25%     61701.500000    0.669566   970.247750
# 50%     82163.500000    0.708779  1120.870000
# ...

# %%
dataFrameTesting.describe()
# Out:
#                 Area  MajorAxisLength  MinorAxisLength  Eccentricity  \
# count     180.000000       180.000000       180.000000    180.000000
# mean    86241.061111       426.008539       252.900855      0.779334
# std     37860.932528       115.681796        47.682468      0.086411
# min     31237.000000       227.293792       155.025743      0.419754
# 25%     58630.000000       344.755839       219.684009      0.741625
# 50%     77267.500000       411.329201       246.148727      0.787960
# 75%    104431.250000       489.838241       277.275843      0.835828
# max    210923.000000       984.045491       402.283271      0.928094
#
#           ConvexArea      Extent    Perimeter
# count     180.000000  180.000000   180.000000
# mean    89513.461111    0.700600  1154.114194
# std     40112.508617    0.047149   274.889804
# min     32564.000000    0.491460   699.415000
# 25%     60592.750000    0.674847   947.277500
# 50%     80054.000000    0.703489  1106.838000
# ...
